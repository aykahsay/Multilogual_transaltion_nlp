# %% [markdown]
# <a href="https://colab.research.google.com/github/aykahsay/Multilogual_transaltion_nlp/blob/main/colab_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PSA Machine Translation Fine-Tuning on Google Colab
#
# This notebook contains the steps to clone your repository and run the training script using Colab's GPU.
#
# **Important Step:** Make sure you go to **Runtime > Change runtime type** and select **T4 GPU** before you begin running the cells!

# %%
# Clone your GitHub repository
# !git clone https://github.com/aykahsay/Multilogual_transaltion_nlp.git
# %cd Multilogual_transaltion_nlp
# Out:
# Cloning into 'Multilogual_transaltion_nlp'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 35 (delta 15), reused 30 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 448.91 KiB | 2.97 MiB/s, done.
# Resolving deltas: 100% (15/15), done.
# /content/Multilogual_transaltion_nlp

# %%
# Install the necessary libraries
# !pip install -r requirements.txt
# !pip install sentencepiece sacremoses evaluate sacrebleu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 33.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 52.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 47.8 MB/s eta 0:00:00
# ...

# %%
# Run the fine-tuning script!
# (This might take a few minutes depending on the data size)
# !python train.py
# Out:
# Loading tokenizer and model: Helsinki-NLP/opus-mt-en-sw
# Loading weights: 100% 258/258 [00:00<00:00, 28989.78it/s]
# ...
# Loading datasets...
# Tokenizing datasets...
# Map: 100% 3832/3832 [00:03<00:00, 1146.44 examples/s]
# Map: 100% 479/479 [00:00<00:00, 2243.37 examples/s]
# Traceback (most recent call last):
#   File "/content/Multilogual_transaltion_nlp/train.py", line 75, in <module>
#     main()
#   File "/content/Multilogual_transaltion_nlp/train.py", line 58, in main
#     trainer = Seq2SeqTrainer(
#               ^^^^^^^^^^^^^^^
# TypeError: Seq2SeqTrainer.__init__() got an unexpected keyword argument 'tokenizer'

# %%
# Evaluate the fine-tuned model
# !python evaluate.py
